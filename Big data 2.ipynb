# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
covid_data = pd.read_csv("Effects-of-COVID-19-on-trade-1-February-18-November-2020-provisional.csv")

# %%
covid_data
# Out:
#        Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 0        Exports  2015  31/01/2015   Saturday     1/02/2020     All       All
# 1        Exports  2015   1/02/2015     Sunday     2/02/2020     All       All
# 2        Exports  2015   2/02/2015     Monday     3/02/2020     All       All
# 3        Exports  2015   3/02/2015    Tuesday     4/02/2020     All       All
# 4        Exports  2015   4/02/2015  Wednesday     5/02/2020     All       All
# ...          ...   ...         ...        ...           ...     ...       ...
# 70042  Reimports  2020  14/11/2020   Saturday    14/11/2020     All       All
# 70043  Reimports  2020  15/11/2020     Sunday    15/11/2020     All       All
# 70044  Reimports  2020  16/11/2020     Monday    16/11/2020     All       All
# 70045  Reimports  2020  17/11/2020    Tuesday    17/11/2020     All       All
# 70046  Reimports  2020  18/11/2020  Wednesday    18/11/2020     All       All
#
# ...

# %%
plt.bar(covid_data.Direction, covid_data.Cumulative, align = "center")
plt.rcParams["figure.figsize"] = [5,5]

# %%
imp = covid_data[covid_data.Direction == "Imports"]
exp = covid_data[covid_data.Direction == "Exports"]
reimp = covid_data[covid_data.Direction == "Reimports"]

# %%
plt.plot(imp.Country, imp.Value, ".")
plt.legend(["Country"])
plt.xlabel("Country")
plt.ylabel("Value")
plt.title("Importation")
plt.show()

# %%
plt.plot(exp.Country, exp.Value, ".")
plt.legend(["Country"])
plt.xticks(rotation = 45)
plt.xlabel("Country")
plt.ylabel("Value")
plt.rcParams['figure.figsize'] = [20,20]
plt.title("Exportation")
plt.show()

# %%
plt.plot(reimp.Country, reimp.Value, "red")
plt.legend(["Country"])
plt.xlabel("Country")
plt.ylabel("Value")
plt.title("Reimportation")
plt.show()

# %%
plt.plot(imp.Year, imp.Value, "*")
plt.legend(["Year"])
plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Importation")
plt.show()

# %%
plt.plot(exp.Year, exp.Value, "*")
plt.legend(["Year"])
plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Exportation")
plt.show()

# %%
plt.plot(reimp.Year, reimp.Value, "*")
plt.legend(["Year"])
plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Reimportation")
plt.show()

# %%
plt.plot(imp.Transport_Mode, imp.Value, "o")
plt.legend(["Transport Mode"])
plt.xlabel("Transport Mode")
plt.ylabel("Value")
plt.rcParams["figure.figsize"] = [5, 5]
plt.title("Importation")
plt.show()

# %%
plt.plot(exp.Transport_Mode, exp.Value, "o")
plt.legend(["Transport Mode"])
plt.xlabel("Transport Mode")
plt.ylabel("Value")
plt.rcParams["figure.figsize"] = [10, 5]
plt.title("Exportation")
plt.show()

# %%
plt.plot(reimp.Transport_Mode, reimp.Value, "o")
plt.legend(["Transport Mode"])
plt.xlabel("Transport Mode")
plt.ylabel("Value")
plt.rcParams["figure.figsize"] = [10, 5]
plt.title("Reimportation")
plt.show()

# %%
plt.plot(imp.Commodity, imp.Value, "+")
plt.legend(["Commodity"])
plt.xlabel("Commodity")
plt.ylabel("Value")
plt.title("Importation")
plt.show()

# %%
plt.plot(exp.Commodity, exp.Value, "+")
plt.xticks(rotation = 45)
plt.legend(["Commodity"])
plt.xlabel("Commodity")
plt.ylabel("Value")
plt.title("Exportation")
plt.show()

# %%
plt.plot(reimp.Commodity, reimp.Value, "+")
plt.legend(["Commodity"])
plt.xlabel("Commodity")
plt.ylabel("Value")
plt.title("Reimportation")
plt.show()
